# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ipl-data-set/matches.csv
# /kaggle/input/ipl-data-set/teamwise_home_and_away.csv
# /kaggle/input/ipl-data-set/deliveries.csv
# /kaggle/input/ipl-data-set/most_runs_average_strikerate.csv
# /kaggle/input/ipl-data-set/teams.csv
# /kaggle/input/ipl-data-set/Players.xlsx

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
matchs_df = pd.read_csv('/kaggle/input/ipl-data-set/matches.csv')
score_df=pd.read_csv('/kaggle/input/ipl-data-set/deliveries.csv')

# %%
matchs_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
score_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
matchs_df.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %%
matchs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
matchs_df.Season.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Season'>

# %%
matchs_df.Season.count()
# Out:
# 756

# %%
matchs_df.team1
# Out:
# 0              Sunrisers Hyderabad
# 1                   Mumbai Indians
# 2                    Gujarat Lions
# 3           Rising Pune Supergiant
# 4      Royal Challengers Bangalore
#                   ...
# 751          Kolkata Knight Riders
# 752            Chennai Super Kings
# 753            Sunrisers Hyderabad
# 754                 Delhi Capitals
# 755                 Mumbai Indians
# Name: team1, Length: 756, dtype: object

# %%
matchs_df.team1.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
matchs_df.Season.unique()
# Out:
# array(['IPL-2017', 'IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011',
#        'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016',
#        'IPL-2018', 'IPL-2019'], dtype=object)

# %%
matchs_df.team2.unique()
# Out:
# array(['Royal Challengers Bangalore', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Deccan Chargers',
#        'Pune Warriors', 'Kochi Tuskers Kerala', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
gb=matchs_df.groupby(['Season'])
gb

# %%
gb.get_group('IPL-2017')
# Out:
#     id    Season        city        date                        team1  \
# 0    1  IPL-2017   Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1    2  IPL-2017        Pune  06-04-2017               Mumbai Indians
# 2    3  IPL-2017      Rajkot  07-04-2017                Gujarat Lions
# 3    4  IPL-2017      Indore  08-04-2017       Rising Pune Supergiant
# 4    5  IPL-2017   Bangalore  08-04-2017  Royal Challengers Bangalore
# 5    6  IPL-2017   Hyderabad  09-04-2017                Gujarat Lions
# 6    7  IPL-2017      Mumbai  09-04-2017        Kolkata Knight Riders
# 7    8  IPL-2017      Indore  10-04-2017  Royal Challengers Bangalore
# 8    9  IPL-2017        Pune  11-04-2017             Delhi Daredevils
# 9   10  IPL-2017      Mumbai  12-04-2017          Sunrisers Hyderabad
# 10  11  IPL-2017     Kolkata  13-04-2017              Kings XI Punjab
# 11  12  IPL-2017   Bangalore  14-04-2017  Royal Challengers Bangalore
# ...

# %%
l=gb.get_group('IPL-2014')
l
# Out:
#       id    Season        city        date                        team1  \
# 457  458  IPL-2014   Abu Dhabi  16-04-2014        Kolkata Knight Riders
# 458  459  IPL-2014     Sharjah  17-04-2014             Delhi Daredevils
# 459  460  IPL-2014   Abu Dhabi  18-04-2014          Chennai Super Kings
# 460  461  IPL-2014   Abu Dhabi  18-04-2014          Sunrisers Hyderabad
# 461  462  IPL-2014         NaN  19-04-2014               Mumbai Indians
# 462  463  IPL-2014         NaN  19-04-2014        Kolkata Knight Riders
# 463  464  IPL-2014     Sharjah  20-04-2014             Rajasthan Royals
# 464  465  IPL-2014   Abu Dhabi  21-04-2014          Chennai Super Kings
# 465  466  IPL-2014     Sharjah  22-04-2014              Kings XI Punjab
# 466  467  IPL-2014         NaN  23-04-2014          Chennai Super Kings
# 467  468  IPL-2014     Sharjah  24-04-2014        Kolkata Knight Riders
# 468  469  IPL-2014         NaN  25-04-2014          Sunrisers Hyderabad
# ...

# %%
l.count()
# Out:
# id                 60
# Season             60
# city               53
# date               60
# team1              60
# team2              60
# toss_winner        60
# toss_decision      60
# result             60
# dl_applied         60
# winner             60
# win_by_runs        60
# win_by_wickets     60
# player_of_match    60
# venue              60
# umpire1            60
# umpire2            60
# umpire3             0
# dtype: int64

# %%
matchs_df.Season.count()
# Out:
# 756

# %%
gb=matchs_df.groupby(['Season'])
gb

# %%
group=gb.get_group('IPL-2017')
group.count()
# Out:
# id                 59
# Season             59
# city               59
# date               59
# team1              59
# team2              59
# toss_winner        59
# toss_decision      59
# result             59
# dl_applied         59
# winner             59
# win_by_runs        59
# win_by_wickets     59
# player_of_match    59
# venue              59
# umpire1            58
# umpire2            58
# umpire3             0
# dtype: int64

# %%
group=gb.get_group('IPL-2008')
group
# Out:
#       id    Season        city        date                        team1  \
# 59    60  IPL-2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 60    61  IPL-2008  Chandigarh  19-04-2008          Chennai Super Kings
# 61    62  IPL-2008       Delhi  19-04-2008             Rajasthan Royals
# 62    63  IPL-2008      Mumbai  20-04-2008               Mumbai Indians
# 63    64  IPL-2008     Kolkata  20-04-2008              Deccan Chargers
# 64    65  IPL-2008      Jaipur  21-04-2008              Kings XI Punjab
# 65    66  IPL-2008   Hyderabad  22-04-2008              Deccan Chargers
# 66    67  IPL-2008     Chennai  23-04-2008          Chennai Super Kings
# 67    68  IPL-2008   Hyderabad  24-04-2008              Deccan Chargers
# 68    69  IPL-2008  Chandigarh  25-04-2008              Kings XI Punjab
# 69    70  IPL-2008   Bangalore  26-04-2008  Royal Challengers Bangalore
# 70    71  IPL-2008     Chennai  26-04-2008        Kolkata Knight Riders
# ...

# %%
group.count()
# Out:
# id                 58
# Season             58
# city               58
# date               58
# team1              58
# team2              58
# toss_winner        58
# toss_decision      58
# result             58
# dl_applied         58
# winner             58
# win_by_runs        58
# win_by_wickets     58
# player_of_match    58
# venue              58
# umpire1            58
# umpire2            58
# umpire3             0
# dtype: int64

# %%
sgpa=matchs_df.groupby('Season')
sgpa.team1.nunique()
# Out:
# Season
# IPL-2008     8
# IPL-2009     8
# IPL-2010     8
# IPL-2011    10
# IPL-2012     9
# IPL-2013     9
# IPL-2014     8
# IPL-2015     8
# IPL-2016     8
# IPL-2017     8
# IPL-2018     8
# IPL-2019     8
# Name: team1, dtype: int64

# %%
df_team=matchs_df.team2.unique()
df_team
# Out:
# array(['Royal Challengers Bangalore', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Deccan Chargers',
#        'Pune Warriors', 'Kochi Tuskers Kerala', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
df_team=matchs_df.team2.nunique()
df_team
# Out:
# 15

# %%
matchs_df.iloc[matchs_df['win_by_runs'].idxmax()]
# Out:
# id                               44
# Season                     IPL-2017
# city                          Delhi
# date                     06-05-2017
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                        0
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# umpire3                         NaN
# Name: 43, dtype: object

# %%
matchs_df.iloc[matchs_df['win_by_wickets'].idxmax()]['winner']
# Out:
# 'Kolkata Knight Riders'

# %%
matchs_df.iloc[matchs_df['win_by_wickets'].idxmax()]['win_by_runs']
# Out:
# 0

# %%
matchs_df.iloc[matchs_df['win_by_wickets'].idxmax()]['win_by_wickets']
# Out:
# 10

# %%
matchs_df.iloc
{matchs_df[matchs_df['win_by_runs'].ge(1)].win_by_runs.idxmin()}
['winner']
# Out:
# ['winner']

# %%
matchs_df.Season.unique()
# Out:
# array(['IPL-2017', 'IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011',
#        'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016',
#        'IPL-2018', 'IPL-2019'], dtype=object)

# %%
gb=matchs_df.groupby('player_of_match')
gb

# %%
wi=gb.nunique()
wi
# Out:
#                    id  Season  city  date  team1  team2  toss_winner  \
# player_of_match
# A Chandila          1       1     1     1      1      1            1
# A Joseph            1       1     1     1      1      1            1
# A Kumble            3       3     3     3      2      2            2
# A Mishra           11       7     5    11      7      7            5
# A Nehra             6       4     5     6      5      3            3
# ...                ..     ...   ...   ...    ...    ...          ...
# Washington Sundar   1       1     1     1      1      1            1
# YK Pathan          16       8     9    16      9      5            7
# YS Chahal           1       1     1     1      1      1            1
# Yuvraj Singh        5       4     5     5      4      4            3
# Z Khan              1       1     1     1      1      1            1
#
#                    toss_decision  result  dl_applied  winner  win_by_runs  \
# player_of_match
# ...

# %%
gb.Season.describe()
# Out:
#                   count unique       top freq
# player_of_match
# A Chandila            1      1  IPL-2012    1
# A Joseph              1      1  IPL-2019    1
# A Kumble              3      3  IPL-2008    1
# A Mishra             11      7  IPL-2013    4
# A Nehra               6      4  IPL-2015    3
# ...                 ...    ...       ...  ...
# Washington Sundar     1      1  IPL-2017    1
# YK Pathan            16      8  IPL-2008    4
# YS Chahal             1      1  IPL-2014    1
# Yuvraj Singh          5      4  IPL-2009    2
# Z Khan                1      1  IPL-2015    1
#
# [226 rows x 4 columns]

# %%
maxe=group.player_of_match.value_counts()
maxe
# Out:
# SE Marsh            5
# SR Watson           4
# YK Pathan           4
# SM Pollock          2
# AC Gilchrist        2
# Sohail Tanvir       2
# ST Jayasuriya       2
# MS Dhoni            2
# SC Ganguly          2
# M Ntini             2
# V Sehwag            2
# SP Goswami          1
# A Kumble            1
# KD Karthik          1
# JA Morkel           1
# DJ Bravo            1
# P Kumar             1
# GC Smith            1
# DPMD Jayawardene    1
# A Mishra            1
# Shoaib Akhtar       1
# Umar Gul            1
# L Balaji            1
# CRD Fernando        1
# BB McCullum         1
# A Nehra             1
# S Sreesanth         1
# MEK Hussey          1
# IK Pathan           1
# R Vinay Kumar       1
# SA Asnodkar         1
# GD McGrath          1
# SM Katich           1
# JDP Oram            1
# KC Sangakkara       1
# ML Hayden           1
# DJ Hussey           1
# MV Boucher          1
# MF Maharoof         1
# SK Raina            1
# Name: player_of_match, dtype: int64

# %%
maxe.head(1)
# Out:
# SE Marsh    5
# Name: player_of_match, dtype: int64

# %%
group.Season.value_counts()
# Out:
# IPL-2008    58
# Name: Season, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='Season',data=matchs_df)
plt.show()

# %%
plt.figure(figsize=(12,6))
data=matchs_df.winner.value_counts()
sns.barplot(y=data.index, x=data, orient='h') 
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='winner',data=matchs_df)
plt.show()

# %%
plt.figure(figsize=(12,6))
data=matchs_df.Season.value_counts()
sns.barplot(y=data.index, x=data, orient='h') 
plt.show()

# %%
top_players=matchs_df.player_of_match.value_counts()[:10]
fig, ax=plt.subplots(figsize=(15,8))
ax.set_ylim([0,20])
ax.set_ylabel("Count")
ax.set_title("Top player of the match winners")
sns.barplot(x=top_players.index, y=top_players, orient='v',palette="Blues")
plt.show()

# %%
top_players=matchs_df.player_of_match.value_counts()[:10]
fig, ax=plt.subplots(figsize=(15,8))
ax.set_ylim([0,20])
ax.set_ylabel("Count")
ax.set_title("Top player of the match winners")
sns.barplot(x=top_players.index, y=top_players, orient='e',palette="Greens")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 6
#       4 ax.set_ylabel("Count")
#       5 ax.set_title("Top player of the match winners")
# ----> 6 sns.barplot(x=top_players.index, y=top_players, orient='e',palette="Greens")
#       7 plt.show()
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
# ...
